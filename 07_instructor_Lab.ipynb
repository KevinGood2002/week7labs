# %%
import os
import pandas as pd
from sklearn.model_selection import KFold

# %% [markdown]
# ### Set working Directory

# %%
os.chdir('C:\\Users\\kevin\\OneDrive\\Documents\\GitHub\\python\\week7labs\\data')

# %% [markdown]
# ### Access Data

# %%
gh_teams = pd.read_csv("github_teams.csv")

# %% [markdown]
# ### inspect columns

# %%
gh_teams.columns
# Out:
# Index(['name_h', 'Team_type', 'Team_size_class', 'human_members_count',
#        'bot_members_count', 'human_work', 'work_per_human', 'human_gini',
#        'human_Push', 'human_IssueComments', 'human_PRReviewComment',
#        'human_MergedPR', 'bot_work', 'bot_Push', 'bot_IssueComments',
#        'bot_PRReviewComment', 'bot_MergedPR', 'eval_survival_day_median',
#        'issues_count'],
#       dtype='object')

# %% [markdown]
# The columns are: 'name_h', 'Team_type', 'Team_size_class', 'human_members_count','bot_members_count', 'human_work', 'work_per_human', 'human_gini','human_Push', 'human_IssueComments', 'human_PRReviewComment','human_MergedPR', 'bot_work', 'bot_Push', 'bot_IssueComments','bot_PRReviewComment', 'bot_MergedPR', 'eval_survival_day_median',
#        'issues_count'],
#       dtype='object'

# %%
len(gh_teams.index)
# Out:
# 608

# %%
len(gh_teams.columns)
# Out:
# 19

# %% [markdown]
# There are 608 rows and 19 columns

# %% [markdown]
# ### Changing Object columns to category columns

# %%
gh_teams.select_dtypes(include = ['object'])
# Out:
#                                             name_h  Team_type Team_size_class
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# [608 rows x 3 columns]

# %%
gh_teams['name_h'] = gh_teams['name_h'].astype('category')
gh_teams['Team_type'] = gh_teams['Team_type'].astype('category')
gh_teams['Team_size_class'] = gh_teams['Team_size_class'].astype('category')

# %% [markdown]
# ### Determining Unique values

# %%
unique_teams = len(gh_teams.Team_type.unique())
print(f'There are {unique_teams} unique team types')
# Out:
# There are 2 unique names

# %%
unique_class_size = len(gh_teams.Team_size_class.unique())
print(f'There are {unique_class_size} unique class sizes')
# Out:
# There are 3 unique class sizes

# %% [markdown]
# ### finding values

# %%
gh_teams.iloc[62,5] #63rd row and 6th column
# Out:
# 35

# %%
gh_teams.iloc[599] #row 600
# Out:
# name_h                      zDxFw19WoS8GFVmQGJXQCw/xsTexXJ1UlUoG5F8Lns-7A
# Team_type                                                       human-bot
# Team_size_class                                                     Large
# human_members_count                                                    59
# bot_members_count                                                       1
# human_work                                                            198
# work_per_human                                                   3.355932
# human_gini                                                       0.189009
# human_Push                                                            114
# human_IssueComments                                                    82
# human_PRReviewComment                                                   2
# human_MergedPR                                                          0
# bot_work                                                                9
# ...

# %%
gh_teams.iloc[595, :3] #first three colums
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[595, 0:3] #first three colums
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.loc[595, 'name_h':'Team_size_class'] #first three colums
# Out:
# name_h             zAh1NECRCquqUJ_-1d6hAw/DET3jTK8hokYfY_neJ1IVQ
# Team_type                                              human-bot
# Team_size_class                                            Small
# Name: 595, dtype: object

# %%
gh_teams.iloc[46, [2, 6]]  # 3rd column is index 2, 7th column is index 6
# Out:
# Team_size_class       Medium
# work_per_human     31.833333
# Name: 46, dtype: object

# %%
gh_teams.loc[46, ['Team_size_class', 'work_per_human']]  # 3rd column is index 2, 7th column is index 6
# Out:
# Team_size_class       Medium
# work_per_human     31.833333
# Name: 46, dtype: object

# %% [markdown]
# ### New Data frame

# %%
gh_teams.bot_work
# Out:
# 0        43
# 1         0
# 2         0
# 3      1972
# 4       302
#        ...
# 603      26
# 604       0
# 605       0
# 606       0
# 607       8
# Name: bot_work, Length: 608, dtype: int64

# %%
just_bot_work = pd.DataFrame(gh_teams.bot_work)
just_bot_work
# Out:
#      bot_work
# 0          43
# 1           0
# 2           0
# 3        1972
# 4         302
# ..        ...
# 603        26
# 604         0
# 605         0
# 606         0
# 607         8
#
# [608 rows x 1 columns]

# %%
just_bot_work = gh_teams[['bot_work']]
just_bot_work
# Out:
#      bot_work
# 0          43
# 1           0
# 2           0
# 3        1972
# 4         302
# ..        ...
# 603        26
# 604         0
# 605         0
# 606         0
# 607         8
#
# [608 rows x 1 columns]

# %% [markdown]
# ### Sort and Order data

# %%
gh_teams[gh_teams.bot_members_count >= 2] ### teams with botmembers>2
# Out:
#                                             name_h  Team_type Team_size_class  \
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# 42   2-scMrZv13F95YPZmfieww/4Zc56iUYjIZrZU06omFrJw  human-bot           Large
# 84   4YoH8row044yJjPIqWJw9Q/NSXj3i61X71lV0StTN71Ww  human-bot           Small
# 89   5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
# 110  7sA-8-nyqr0Ri2CT4-FSZw/GJPQoUhHfvUsxKcdkHWLEw  human-bot           Small
# 146  bi5TY2Z4OSQq3PMs6JnKYA/5wtZcUUo1XmLHIra8NDtFQ  human-bot          Medium
# 147  bi5TY2Z4OSQq3PMs6JnKYA/9b9IqkDK14ketwn88f3hKA  human-bot           Small
# 149  bi5TY2Z4OSQq3PMs6JnKYA/kIiAIJpk6lOa6Nxf234KkQ  human-bot           Small
# 224  FAhkB4rsocfDW0vrM8U8NA/3KHgTzOwWtAxTXlp_mbqoA  human-bot           Large
# 229  FAhkB4rsocfDW0vrM8U8NA/Tl_ZLGwQZrAi-GHyEKl_jA  human-bot           Large
# ...

# %%
gh_teams[(gh_teams.Team_size_class == 'Large') & (gh_teams.human_gini >= 0.75)] # Large teams with human_gini ≥ 0.75
# Out:
#                                             name_h  Team_type Team_size_class  \
# 37   0YuGJKD19yHae4I2X8Vi3Q/gWpl7HC8bRe4tH8S7ASf9w  human-bot           Large
# 138  ASYGR96YA91p3z7MNKjZCA/IB2pZ8ygcvNnlxUdysjSFA      human           Large
# 170  ChhIzGQNr9tq7mCMZw17FA/EUzOBM0WRT3A0AqDDgZ7gw  human-bot           Large
# 232  fCU0oLsk2VDqt1FQd442wQ/vw66CigJCpLmnGJpmxSrwg  human-bot           Large
# 247  G4ciXHNLCpNOnOM__FPJzg/v1eHYw68dE0va5OeQQoAig  human-bot           Large
# 271  HzhwvidPbEmz4xoMZyiVfw/sLD5mQnrR9IArF8AF21IGA  human-bot           Large
# 285  IiUao8vA_zm_uEIVVLI-Sw/91ya8vlSP8qgwCllH_6BSw      human           Large
# 325  kpY6vTbIlrk6Nrjilv8zhw/o_e0F16zwdovR3aFgIQipQ  human-bot           Large
# 399  pDznmccVVZslZAFX5Ym9tg/ErpiGQ6eLenplfEQTat6ww  human-bot           Large
# 473  sq4hB0bA5jL3X3tvK_-stg/G5WoDm7Rms4zNbJ3nc6hZA  human-bot           Large
# 505  uLHPO58cQefwrJUbyhYOKQ/7YWOP8uDEeKDHQMWKqOoYA      human           Large
# ...

# %%
gh_teams[gh_teams.Team_size_class.isin(['Small', 'Large'])].shape[0]  # Number of teams that are Small or Large
# Out:
# 428

# %%
gh_teams[(gh_teams.Team_size_class.isin(['Small', 'Large'])) & (gh_teams.human_gini <= 0.20)].shape[0]  # Small or Large teams with human_gini ≤ 0.20
# Out:
# 66

# %%
gh_teams[(gh_teams.Team_type == 'human-bot') & (gh_teams.Team_size_class == 'Medium')].shape[0]  # Count of human-bot teams that are Medium
# Out:
# 84

# %%
gh_subsample = gh_teams.sample(frac=0.5, random_state=42)  # 50% random subsample with reproducibility
gh_subsample
# Out:
#                                             name_h  Team_type Team_size_class  \
# 109  7R4RlGuxT82BQcun7raI2A/qMXTUX8UDZFqbyxir5YUaA      human           Large
# 10   -2eEmMGH_9GMVVn0WImTyA/fqB6po6-zxOceVyOZhgyNg  human-bot           Large
# 184  DevSiHbJAM-XpY7qknTWIA/ZQC28gcQYc30ailijMZxIg      human          Medium
# 77   4bzOzx-_iEqw2tTZAGgCBQ/o5j7d9925hU99XzWX9CnxQ      human           Small
# 538  vpAJthlySeoTSTCzS0iH9w/WC1ULBuXAws4mFhHGkKRrg  human-bot           Small
# ..                                             ...        ...             ...
# 175  Cqre8Re6M01XbwaSHT3Kcg/Fa3_w52dfYiqleA7ZNNJWg      human           Small
# 507  uLvKXX_6CJ4zG3V_9-fGRw/YGzgdzxRGvwVZcszx5HyCA  human-bot           Small
# 352  Mm3jjXrvOd6zcmzS4gGOxw/fAKHKj6riFXfyVUj1I5xgg  human-bot          Medium
# 194  doQNUrl6BEIxCLiFg1qlsw/jiraBJMqLKwImJ6-mziS_A  human-bot          Medium
# 512  uRRk49zuEXdW4_9yY1dJYQ/nCBlsYUCZYe6TPM_Fxd5aw      human           Large
#
# ...

# %%
kf = KFold(n_splits=8, shuffle=True, random_state=42)  # 8-fold cross-validation with shuffling

for fold, (train_index, test_index) in enumerate(kf.split(gh_teams)):
    print(f"Fold {fold+1}")
    train_set = gh_teams.iloc[train_index]
    test_set = gh_teams.iloc[test_index]
    print(f"Train size: {len(train_set)}, Test size: {len(test_set)}\n")
# Out:
# Fold 1
# Train size: 532, Test size: 76
#
# Fold 2
# Train size: 532, Test size: 76
#
# Fold 3
# Train size: 532, Test size: 76
#
# Fold 4
# Train size: 532, Test size: 76
#
# Fold 5
# Train size: 532, Test size: 76
#
# Fold 6
# Train size: 532, Test size: 76
#
# Fold 7
# Train size: 532, Test size: 76
#
# Fold 8
# Train size: 532, Test size: 76

# %%
gh_numeric = gh_teams.select_dtypes(include='number')  # Select only numeric columns
gh_numeric
# Out:
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 0                      2                  1          66       33.000000
# 1                      2                  0          62       31.000000
# 2                      7                  0         211       30.142857
# 3                    234                 12       14579       62.303419
# 4                     38                  8        1625       42.763158
# ..                   ...                ...         ...             ...
# 603                    3                  1         855      285.000000
# 604                    2                  0          63       31.500000
# 605                    5                  0          26        5.200000
# 606                    5                  0          13        2.600000
# 607                    2                  1          57       28.500000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# ...

# %%
gh_numeric = gh_teams.drop(columns=['bot_PRReviewComment', 'bot_MergedPR'])  # Remove specified columns
gh_numeric
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %%
team_info = gh_teams[['Team_size_class', 'human_members_count']]  # Save selected columns to new DataFrame
team_info
# Out:
#     Team_size_class  human_members_count
# 0             Small                    2
# 1             Small                    2
# 2             Large                    7
# 3             Large                  234
# 4             Large                   38
# ..              ...                  ...
# 603           Small                    3
# 604           Small                    2
# 605          Medium                    5
# 606          Medium                    5
# 607           Small                    2
#
# [608 rows x 2 columns]

# %%
team_info = team_info.rename(columns={
    'Team_size_class': 'Size_Class',
    'human_members_count': 'Num_Humans'
})  # Rename columns
team_info
# Out:
#     Size_Class  Num_Humans
# 0        Small           2
# 1        Small           2
# 2        Large           7
# 3        Large         234
# 4        Large          38
# ..         ...         ...
# 603      Small           3
# 604      Small           2
# 605     Medium           5
# 606     Medium           5
# 607      Small           2
#
# [608 rows x 2 columns]

# %% [markdown]
# References: https://chatgpt.com/c/67fdc4f9-8e80-8001-a133-33dd8cc958d8
